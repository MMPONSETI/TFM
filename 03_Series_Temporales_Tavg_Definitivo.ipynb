# %%
# !pip install meteostat pandas scikit-learn tensorflow statsmodels
# Out:
# Requirement already satisfied: meteostat in c:\users\mpons\anaconda3\lib\site-packages (1.6.7)
# Requirement already satisfied: pandas in c:\users\mpons\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: scikit-learn in c:\users\mpons\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: tensorflow in c:\users\mpons\anaconda3\lib\site-packages (2.15.0)
# Requirement already satisfied: statsmodels in c:\users\mpons\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: pytz in c:\users\mpons\anaconda3\lib\site-packages (from meteostat) (2023.3.post1)
# Requirement already satisfied: numpy in c:\users\mpons\anaconda3\lib\site-packages (from meteostat) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mpons\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\mpons\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\mpons\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\mpons\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mpons\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\mpons\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\mpons\anaconda3\lib\site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\mpons\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\mpons\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.26.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\mpons\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\mpons\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\mpons\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\mpons\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\mpons\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\mpons\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mpons\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mpons\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\mpons\anaconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mpons\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mpons\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mpons\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mpons\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\mpons\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\mpons\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\mpons\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)

# %%
import pandas as pd
from meteostat import Point, Daily
from datetime import datetime
import matplotlib.pyplot as plt

# Definir las coordenadas de las ciudades
cities = {
    'Alicante': Point(38.3452, -0.4810),
    'Palma': Point(39.5696, 2.6502),
    'Las Palmas': Point(28.1235, -15.4363),
    'Girona': Point(41.9818, 2.8249),
    'Malaga': Point(36.7213, -4.4216)
}

# Definir el rango de fechas
start = datetime(2010, 1, 1)
end = datetime(2023, 12, 31)

# Crear una lista para almacenar los datos de todas las ciudades
all_data_list = []

# Obtener los datos de cada ciudad y concatenar en un solo DataFrame
for city, point in cities.items():
    # Obtener los datos diarios de Meteostat
    data = Daily(point, start, end)
    data = data.fetch()
    
    # Agregar columna para la ciudad
    data['city'] = city
    
    # Agregar los datos a la lista
    all_data_list.append(data)

# Concatenar todos los datos en un solo DataFrame
all_data = pd.concat(all_data_list).reset_index()

# Resamplear los datos a frecuencia mensual 'MS' y calcular la media
all_data['time'] = pd.to_datetime(all_data['time'])
all_data.set_index('time', inplace=True)
datos_todo = all_data.groupby('city').resample('MS').mean().reset_index()

# Visualización de los datos
print(datos_todo.head())
datos_todo.shape
# Out:
# Warning: Cannot load daily/08301.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/08302.csv.gz from https://bulk.meteostat.net/v2/
#        city       time       tavg       tmin       tmax      prcp  snow  \
# 0  Alicante 2010-01-01  12.470968   6.974194  15.019355  1.310714   NaN
# 1  Alicante 2010-02-01  11.882143   7.217857  16.464286  0.670370   NaN
# 2  Alicante 2010-03-01  12.748387   7.809677  17.177419  1.180000   NaN
# 3  Alicante 2010-04-01  15.806667  10.760000  19.966667  0.483333   NaN
# 4  Alicante 2010-05-01  18.761290  13.174194  23.335484  0.892857   NaN
#
#          wdir       wspd  wpgt         pres  tsun
# 0  220.920000  14.890323   NaN  1014.580645   NaN
# 1  255.818182  12.189286   NaN  1008.910714   NaN
# 2  203.952381  11.229032   NaN  1018.053571   NaN
# 3  122.095238  10.816667   NaN  1017.375862   NaN
# 4  208.294118  10.751613   NaN  1014.441935   NaN
# (840, 12)

# %%
#Regresión lineal
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

def preparar_datos_regresion(data, ciudad):
    ciudad_data = data[data['city'] == ciudad].set_index('time')
    X = np.array((ciudad_data.index.year * 12 + ciudad_data.index.month).values).reshape(-1, 1)
    y = ciudad_data['tavg'].values
    return X, y, ciudad_data.index

# Definir un DataFrame para almacenar las predicciones
predicciones_regresion = pd.DataFrame()

# Aplicar el modelo de regresión lineal para cada ciudad
for city in cities.keys():
    X, y, dates = preparar_datos_regresion(datos_todo, city)
    model = LinearRegression().fit(X, y)
    
    # Predicciones para los años 2024, 2025 y 2026
    future_X = np.array([(year * 12 + month) for year in range(2024, 2027) for month in range(1, 13)]).reshape(-1, 1)
    future_dates = pd.date_range(start='2024-01-01', end='2026-12-01', freq='MS')
    future_pred = model.predict(future_X)
    
    # Calcular el accuracy
    y_pred = model.predict(X)
    mse = mean_squared_error(y, y_pred)
    rmse = np.sqrt(mse)
    
    # Agregar las predicciones al DataFrame
    df_pred = pd.DataFrame({'time': future_dates, 'tavg': future_pred, 'city': city})
    predicciones_regresion = pd.concat([predicciones_regresion, df_pred])
    
    print(f'Regresión Lineal para {city} - RMSE: {rmse:.2f}')
    print("coeficiente", model.coef_)
    
    # Graficar resultados
    plt.figure(figsize=(10, 5))
    plt.plot(dates, y, label='Datos Históricos')
    plt.plot(dates, y_pred, label='Predicción Entrenamiento', color='red')
    plt.plot(future_dates, future_pred, label='Predicción Futuro', color='green')
    plt.xlabel('Fecha')
    plt.ylabel('Temperatura Promedio (°C)')
    plt.title(f'Regresión Lineal de Temperatura Promedio en {city}')
    plt.legend()
    plt.show()
# Out:
# Regresión Lineal para Alicante - RMSE: 5.52
# coeficiente [0.00653739]
# Regresión Lineal para Palma - RMSE: 5.81
# coeficiente [0.01317471]
# Regresión Lineal para Las Palmas - RMSE: 2.48
# coeficiente [0.00377038]
# Regresión Lineal para Girona - RMSE: 6.15
# coeficiente [0.00905946]
# Regresión Lineal para Malaga - RMSE: 5.06
# coeficiente [0.00803061]

# %%
#Redes Neuronales Recurrentes: RNN
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler

def preparar_datos_rnn(data, ciudad):
    ciudad_data = data[data['city'] == ciudad].set_index('time')
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(ciudad_data[['tavg']])

    X, y = [], []
    for i in range(12, len(scaled_data)):
        X.append(scaled_data[i-12:i])
        y.append(scaled_data[i])
    
    X = np.array(X)
    y = np.array(y)
    return X, y, scaler, ciudad_data.index

# Definir un DataFrame para almacenar las predicciones
predicciones_rnn = pd.DataFrame()

# Aplicar el modelo RNN para cada ciudad
for city in cities.keys():
    X, y, scaler, dates = preparar_datos_rnn(datos_todo, city)
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.SimpleRNN(50, activation='relu', input_shape=(X.shape[1], X.shape[2])),
        tf.keras.layers.Dense(1)
    ])
    
    model.compile(optimizer='adam', loss='mse')
    model.fit(X, y, epochs=100, verbose=0)
    
    y_pred = model.predict(X)
    y_pred = scaler.inverse_transform(y_pred)
    mse = mean_squared_error(scaler.inverse_transform(y), y_pred)
    rmse = np.sqrt(mse)
    
    # Predicciones para los años 2024, 2025 y 2026
    future_pred = []
    future_X = X[-1].reshape(1, X.shape[1], X.shape[2])
    
    for _ in range(36):
        next_pred = model.predict(future_X)
        future_pred.append(next_pred[0, 0])
        next_input = np.append(future_X[0, 1:], next_pred)
        future_X = next_input.reshape(1, X.shape[1], X.shape[2])
    
    future_pred = scaler.inverse_transform(np.array(future_pred).reshape(-1, 1)).flatten()
    future_dates = pd.date_range(start='2024-01-01', end='2026-12-01', freq='MS')
    
    # Agregar las predicciones al DataFrame
    df_pred = pd.DataFrame({'time': future_dates, 'tavg': future_pred, 'city': city})
    predicciones_rnn = pd.concat([predicciones_rnn, df_pred])
    
    print(f'RNN para {city} - RMSE: {rmse:.2f}')
    
    # Graficar resultados
    plt.figure(figsize=(10, 5))
    plt.plot(dates[12:], scaler.inverse_transform(y), label='Datos Históricos')
    plt.plot(dates[12:], y_pred, label='Predicción Entrenamiento', color='red')
    plt.plot(future_dates, future_pred, label='Predicción Futuro', color='green')
    plt.xlabel('Fecha')
    plt.ylabel('Temperatura Promedio (°C)')
    plt.title(f'Redes Neuronales Recurrentes (RNN) en {city}')
    plt.legend()
    plt.show()
# Out:
# WARNING:tensorflow:From C:\Users\mpons\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\mpons\anaconda3\Lib\site-packages\keras\src\layers\rnn\simple_rnn.py:130: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\mpons\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\mpons\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 5/5 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# RNN para Alicante - RMSE: 1.03
# 5/5 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# RNN para Palma - RMSE: 0.96
# 5/5 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 45ms/step
# RNN para Las Palmas - RMSE: 0.56
# 5/5 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 47ms/step
# RNN para Girona - RMSE: 1.22
# 5/5 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 47ms/step
# RNN para Malaga - RMSE: 0.78

# %%
#ARIMA
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error

# Definir un DataFrame para almacenar las predicciones
predicciones_arima = pd.DataFrame()

# Aplicar el modelo ARIMA para cada ciudad
for city in cities.keys():
    ciudad_data = datos_todo[datos_todo['city'] == city].set_index('time')['tavg'].dropna()
    
    # Ajustar el modelo ARIMA
    model = sm.tsa.ARIMA(ciudad_data, order=(1, 1, 1))
    model_fit = model.fit()
    print(f"Resumen del modelo ARIMA para {city}:")
    print(model_fit.summary())
    
    # Predicciones dentro de la muestra
    y_pred = model_fit.predict(start=0, end=len(ciudad_data)-1, typ='levels')
    mse = mean_squared_error(ciudad_data, y_pred)
    rmse = np.sqrt(mse)
    
    # Predicciones fuera de la muestra (2024-2026)
    future_pred = model_fit.predict(start=0, end=179, typ='levels')
    future_dates = pd.date_range(start='2012-01-01', end='2026-12-01', freq='MS')
    
    # Agregar las predicciones al DataFrame
    df_pred = pd.DataFrame({'time': future_dates, 'tavg': future_pred, 'city': city})
    predicciones_arima = pd.concat([predicciones_arima, df_pred])
    aic = model_fit.aic
    print(f'ARIMA para {city} - RMSE: {rmse:.2f}')
    print(f'El valor AIC del modelo para {city} es: {aic}')
    # Graficar resultados
    plt.figure(figsize=(10, 5))
    plt.plot(ciudad_data.index, ciudad_data.values, label='Datos Históricos')
    plt.plot(ciudad_data.index, y_pred, label='Predicción Entrenamiento', color='red')
    plt.plot(future_dates, future_pred, label='Predicción Futuro', color='green')
    plt.xlabel('Fecha')
    plt.ylabel('Temperatura Promedio (ºC)')
    plt.title(f'ARIMA en {city}')
    plt.legend()
    plt.show()
# Out:
# ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# Resumen del modelo ARIMA para Alicante:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   tavg   No. Observations:                  168
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -374.755
# Date:                Sat, 15 Jun 2024   AIC                            755.509
# Time:                        16:32:52   BIC                            764.863
# Sample:                    01-01-2010   HQIC                           759.306
#                          - 12-01-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6023      0.104      5.765      0.000       0.398       0.807
# ma.L1          0.1437      0.116      1.236      0.217      -0.084       0.372
# sigma2         5.1881      0.641      8.093      0.000       3.932       6.445
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.11   Jarque-Bera (JB):                 2.93
# Prob(Q):                              0.74   Prob(JB):                         0.23
# Heteroskedasticity (H):               1.18   Skew:                             0.27
# Prob(H) (two-sided):                  0.53   Kurtosis:                         2.63
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ARIMA para Alicante - RMSE: 2.47
# El valor AIC del modelo para Alicante es: 755.5091567335567
# FutureWarning: Unknown keyword arguments: dict_keys(['typ']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# FutureWarning: Unknown keyword arguments: dict_keys(['typ']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# Resumen del modelo ARIMA para Palma:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   tavg   No. Observations:                  168
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -385.596
# Date:                Sat, 15 Jun 2024   AIC                            777.192
# Time:                        16:32:55   BIC                            786.546
# Sample:                    01-01-2010   HQIC                           780.988
#                          - 12-01-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5967      0.103      5.817      0.000       0.396       0.798
# ma.L1          0.1235      0.128      0.966      0.334      -0.127       0.374
# sigma2         5.9089      0.694      8.511      0.000       4.548       7.270
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):                 0.51
# Prob(Q):                              0.80   Prob(JB):                         0.78
# Heteroskedasticity (H):               0.95   Skew:                             0.11
# Prob(H) (two-sided):                  0.84   Kurtosis:                         2.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ARIMA para Palma - RMSE: 2.55
# El valor AIC del modelo para Palma es: 777.1915600565663
# ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# FutureWarning: Unknown keyword arguments: dict_keys(['typ']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# Resumen del modelo ARIMA para Las Palmas:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   tavg   No. Observations:                  168
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -274.412
# Date:                Sat, 15 Jun 2024   AIC                            554.824
# Time:                        16:32:55   BIC                            564.178
# Sample:                    01-01-2010   HQIC                           558.621
#                          - 12-01-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5883      0.131      4.502      0.000       0.332       0.844
# ma.L1         -0.0928      0.150     -0.618      0.536      -0.387       0.201
# sigma2         1.5629      0.175      8.948      0.000       1.221       1.905
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):                 0.28
# Prob(Q):                              0.75   Prob(JB):                         0.87
# Heteroskedasticity (H):               1.37   Skew:                             0.04
# Prob(H) (two-sided):                  0.24   Kurtosis:                         3.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ARIMA para Las Palmas - RMSE: 1.92
# El valor AIC del modelo para Las Palmas es: 554.8243736452749
# ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# FutureWarning: Unknown keyword arguments: dict_keys(['typ']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# Resumen del modelo ARIMA para Girona:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   tavg   No. Observations:                  168
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -411.893
# Date:                Sat, 15 Jun 2024   AIC                            829.786
# Time:                        16:32:56   BIC                            839.140
# Sample:                    01-01-2010   HQIC                           833.582
#                          - 12-01-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5969      0.107      5.595      0.000       0.388       0.806
# ma.L1          0.0018      0.133      0.013      0.989      -0.258       0.262
# sigma2         8.1037      1.018      7.961      0.000       6.109      10.099
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 1.30
# Prob(Q):                              0.96   Prob(JB):                         0.52
# Heteroskedasticity (H):               1.19   Skew:                             0.03
# Prob(H) (two-sided):                  0.51   Kurtosis:                         2.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ARIMA para Girona - RMSE: 2.88
# El valor AIC del modelo para Girona es: 829.7856127763785
# ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# FutureWarning: Unknown keyword arguments: dict_keys(['typ']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# Resumen del modelo ARIMA para Malaga:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   tavg   No. Observations:                  168
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -352.689
# Date:                Sat, 15 Jun 2024   AIC                            711.378
# Time:                        16:32:56   BIC                            720.732
# Sample:                    01-01-2010   HQIC                           715.175
#                          - 12-01-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6301      0.092      6.839      0.000       0.449       0.811
# ma.L1          0.1526      0.114      1.341      0.180      -0.070       0.376
# sigma2         3.9816      0.536      7.426      0.000       2.931       5.032
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.26   Jarque-Bera (JB):                 3.26
# Prob(Q):                              0.61   Prob(JB):                         0.20
# Heteroskedasticity (H):               1.33   Skew:                            -0.07
# Prob(H) (two-sided):                  0.29   Kurtosis:                         2.33
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ARIMA para Malaga - RMSE: 2.20
# El valor AIC del modelo para Malaga es: 711.377981540696

# %% [markdown]
# Resumen
# Obtención de Datos: Los datos se obtienen de Meteostat y se resamplean a una frecuencia mensual.
# Modelos:
# Regresión Lineal: Utilizamos scikit-learn para ajustar un modelo de regresión lineal.
# RNN: Utilizamos tensorflow para entrenar una Red Neuronal Recurrente.
# ARIMA: Utilizamos statsmodels para ajustar un modelo ARIMA.
# Este enfoque te permitirá comparar diferentes modelos de series temporales para predecir la temperatura promedio mensual en diferentes ciudades.

# %%
# Combinar todas las predicciones en un solo DataFrame
predicciones_todas = pd.concat([predicciones_regresion, predicciones_rnn, predicciones_arima])

# Graficar las predicciones para cada ciudad
for city in cities.keys():
    plt.figure(figsize=(12, 6))
    
    # Datos históricos
    ciudad_data = datos_todo[datos_todo['city'] == city].set_index('time')['tavg'].dropna()
    plt.plot(ciudad_data.index, ciudad_data.values, label='Datos Históricos')
    
    # Predicciones de Regresión Lineal
    pred_reg = predicciones_regresion[predicciones_regresion['city'] == city].set_index('time')['tavg']
    plt.plot(pred_reg.index, pred_reg.values, label='Regresión Lineal', color='red')
    
    # Predicciones de RNN
    pred_rnn = predicciones_rnn[predicciones_rnn['city'] == city].set_index('time')['tavg']
    plt.plot(pred_rnn.index, pred_rnn.values, label='RNN', color='green')
    
    # Predicciones de ARIMA
    pred_arima = predicciones_arima[(predicciones_arima['city'] == city) & (predicciones_arima['time'] > '2023-12-31')].set_index('time')['tavg']
    plt.plot(pred_arima.index, pred_arima.values, label='ARIMA', color='grey')
    
    plt.xlabel('Fecha')
    plt.ylabel('Temperatura Promedio (°C)')
    plt.title(f'Predicciones de Temperatura Promedio en {city}')
    plt.legend()
    plt.show()
